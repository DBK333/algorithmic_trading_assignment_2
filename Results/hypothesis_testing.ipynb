# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/AlgoA2/Test\ Result
# Out:
# BB_FILTER_ONLY_with_IWM_0.json	 EMA_ATR_with_SPY_0.json
# BB_FILTER_ONLY_with_IWM_10.json  EMA_ATR_with_SPY_10.json
# BB_FILTER_ONLY_with_IWM_11.json  EMA_ATR_with_SPY_11.json
# BB_FILTER_ONLY_with_IWM_1.json	 EMA_ATR_with_SPY_1.json
# BB_FILTER_ONLY_with_IWM_2.json	 EMA_ATR_with_SPY_2.json
# BB_FILTER_ONLY_with_IWM_3.json	 EMA_ATR_with_SPY_3.json
# BB_FILTER_ONLY_with_IWM_4.json	 EMA_ATR_with_SPY_4.json
# BB_FILTER_ONLY_with_IWM_5.json	 EMA_ATR_with_SPY_5.json
# BB_FILTER_ONLY_with_IWM_6.json	 EMA_ATR_with_SPY_6.json
# BB_FILTER_ONLY_with_IWM_7.json	 EMA_ATR_with_SPY_7.json
# BB_FILTER_ONLY_with_IWM_8.json	 EMA_ATR_with_SPY_8.json
# BB_FILTER_ONLY_with_IWM_9.json	 EMA_ATR_with_SPY_9.json
# BB_FILTER_ONLY_with_RWM_0.json	 EMA_with_ATR_with_IWM_0.json
# BB_FILTER_ONLY_with_RWM_10.json  EMA_with_ATR_with_IWM_10.json
# BB_FILTER_ONLY_with_RWM_11.json  EMA_with_ATR_with_IWM_11.json
# BB_FILTER_ONLY_with_RWM_1.json	 EMA_with_ATR_with_IWM_1.json
# BB_FILTER_ONLY_with_RWM_2.json	 EMA_with_ATR_with_IWM_2.json
# BB_FILTER_ONLY_with_RWM_3.json	 EMA_with_ATR_with_IWM_3.json
# BB_FILTER_ONLY_with_RWM_4.json	 EMA_with_ATR_with_IWM_4.json
# BB_FILTER_ONLY_with_RWM_5.json	 EMA_with_ATR_with_IWM_5.json
# BB_FILTER_ONLY_with_RWM_6.json	 EMA_with_ATR_with_IWM_6.json
# BB_FILTER_ONLY_with_RWM_7.json	 EMA_with_ATR_with_IWM_7.json
# BB_FILTER_ONLY_with_RWM_8.json	 EMA_with_ATR_with_IWM_8.json
# BB_FILTER_ONLY_with_RWM_9.json	 EMA_with_ATR_with_IWM_9.json
# BB_FILTER_ONLY_with_SH_0.json	 RSI_FILTER_ONLY_with_IWM_0.json
# BB_FILTER_ONLY_with_SH_10.json	 RSI_FILTER_ONLY_with_IWM_10.json
# BB_FILTER_ONLY_with_SH_11.json	 RSI_FILTER_ONLY_with_IWM_11.json
# BB_FILTER_ONLY_with_SH_1.json	 RSI_FILTER_ONLY_with_IWM_1.json
# BB_FILTER_ONLY_with_SH_2.json	 RSI_FILTER_ONLY_with_IWM_2.json
# BB_FILTER_ONLY_with_SH_3.json	 RSI_FILTER_ONLY_with_IWM_3.json
# BB_FILTER_ONLY_with_SH_4.json	 RSI_FILTER_ONLY_with_IWM_4.json
# BB_FILTER_ONLY_with_SH_5.json	 RSI_FILTER_ONLY_with_IWM_5.json
# BB_FILTER_ONLY_with_SH_6.json	 RSI_FILTER_ONLY_with_IWM_6.json
# BB_FILTER_ONLY_with_SH_7.json	 RSI_FILTER_ONLY_with_IWM_7.json
# BB_FILTER_ONLY_with_SH_8.json	 RSI_FILTER_ONLY_with_IWM_8.json
# BB_FILTER_ONLY_with_SH_9.json	 RSI_FILTER_ONLY_with_IWM_9.json
# BB_FILTER_ONLY_with_SPY_0.json	 RSI_FILTER_ONLY_with_RWM_0.json
# BB_FILTER_ONLY_with_SPY_10.json  RSI_FILTER_ONLY_with_RWM_10.json
# BB_FILTER_ONLY_with_SPY_11.json  RSI_FILTER_ONLY_with_RWM_11.json
# BB_FILTER_ONLY_with_SPY_1.json	 RSI_FILTER_ONLY_with_RWM_1.json
# BB_FILTER_ONLY_with_SPY_2.json	 RSI_FILTER_ONLY_with_RWM_2.json
# BB_FILTER_ONLY_with_SPY_3.json	 RSI_FILTER_ONLY_with_RWM_3.json
# BB_FILTER_ONLY_with_SPY_4.json	 RSI_FILTER_ONLY_with_RWM_4.json
# BB_FILTER_ONLY_with_SPY_5.json	 RSI_FILTER_ONLY_with_RWM_5.json
# BB_FILTER_ONLY_with_SPY_6.json	 RSI_FILTER_ONLY_with_RWM_6.json
# BB_FILTER_ONLY_with_SPY_7.json	 RSI_FILTER_ONLY_with_RWM_7.json
# BB_FILTER_ONLY_with_SPY_8.json	 RSI_FILTER_ONLY_with_RWM_8.json
# BB_FILTER_ONLY_with_SPY_9.json	 RSI_FILTER_ONLY_with_RWM_9.json
# BENCHMARK_DCA_with_IWM_0.json	 RSI_FILTER_ONLY_with_SH_0.json
# BENCHMARK_DCA_with_IWM_10.json	 RSI_FILTER_ONLY_with_SH_10.json
# BENCHMARK_DCA_with_IWM_11.json	 RSI_FILTER_ONLY_with_SH_11.json
# BENCHMARK_DCA_with_IWM_1.json	 RSI_FILTER_ONLY_with_SH_1.json
# BENCHMARK_DCA_with_IWM_2.json	 RSI_FILTER_ONLY_with_SH_2.json
# BENCHMARK_DCA_with_IWM_3.json	 RSI_FILTER_ONLY_with_SH_3.json
# BENCHMARK_DCA_with_IWM_4.json	 RSI_FILTER_ONLY_with_SH_4.json
# BENCHMARK_DCA_with_IWM_5.json	 RSI_FILTER_ONLY_with_SH_5.json
# BENCHMARK_DCA_with_IWM_6.json	 RSI_FILTER_ONLY_with_SH_6.json
# BENCHMARK_DCA_with_IWM_7.json	 RSI_FILTER_ONLY_with_SH_7.json
# BENCHMARK_DCA_with_IWM_8.json	 RSI_FILTER_ONLY_with_SH_8.json
# BENCHMARK_DCA_with_IWM_9.json	 RSI_FILTER_ONLY_with_SH_9.json
# BENCHMARK_DCA_with_RWM_0.json	 RSI_FILTER_ONLY_with_SPY_0.json
# BENCHMARK_DCA_with_RWM_10.json	 RSI_FILTER_ONLY_with_SPY_10.json
# BENCHMARK_DCA_with_RWM_11.json	 RSI_FILTER_ONLY_with_SPY_11.json
# BENCHMARK_DCA_with_RWM_1.json	 RSI_FILTER_ONLY_with_SPY_1.json
# BENCHMARK_DCA_with_RWM_2.json	 RSI_FILTER_ONLY_with_SPY_2.json
# BENCHMARK_DCA_with_RWM_3.json	 RSI_FILTER_ONLY_with_SPY_3.json
# BENCHMARK_DCA_with_RWM_4.json	 RSI_FILTER_ONLY_with_SPY_4.json
# BENCHMARK_DCA_with_RWM_5.json	 RSI_FILTER_ONLY_with_SPY_5.json
# BENCHMARK_DCA_with_RWM_6.json	 RSI_FILTER_ONLY_with_SPY_6.json
# BENCHMARK_DCA_with_RWM_7.json	 RSI_FILTER_ONLY_with_SPY_7.json
# BENCHMARK_DCA_with_RWM_8.json	 RSI_FILTER_ONLY_with_SPY_8.json
# BENCHMARK_DCA_with_RWM_9.json	 RSI_FILTER_ONLY_with_SPY_9.json
# BENCHMARK_DCA_with_SH_0.json	 sharpe.csv
# BENCHMARK_DCA_with_SH_10.json	 SMA_with_ATR_with_IWM_0.json
# BENCHMARK_DCA_with_SH_11.json	 SMA_with_ATR_with_IWM_10.json
# BENCHMARK_DCA_with_SH_1.json	 SMA_with_ATR_with_IWM_11.json
# BENCHMARK_DCA_with_SH_2.json	 SMA_with_ATR_with_IWM_1.json
# BENCHMARK_DCA_with_SH_3.json	 SMA_with_ATR_with_IWM_2.json
# BENCHMARK_DCA_with_SH_4.json	 SMA_with_ATR_with_IWM_3.json
# BENCHMARK_DCA_with_SH_5.json	 SMA_with_ATR_with_IWM_4.json
# BENCHMARK_DCA_with_SH_6.json	 SMA_with_ATR_with_IWM_5.json
# BENCHMARK_DCA_with_SH_7.json	 SMA_with_ATR_with_IWM_6.json
# BENCHMARK_DCA_with_SH_8.json	 SMA_with_ATR_with_IWM_7.json
# BENCHMARK_DCA_with_SH_9.json	 SMA_with_ATR_with_IWM_8.json
# BENCHMARK_DCA_with_SPY_0.json	 SMA_with_ATR_with_IWM_9.json
# BENCHMARK_DCA_with_SPY_10.json	 SMA_with_ATR_with_RWM_0.json
# BENCHMARK_DCA_with_SPY_11.json	 SMA_with_ATR_with_RWM_10.json
# BENCHMARK_DCA_with_SPY_1.json	 SMA_with_ATR_with_RWM_11.json
# BENCHMARK_DCA_with_SPY_2.json	 SMA_with_ATR_with_RWM_1.json
# BENCHMARK_DCA_with_SPY_3.json	 SMA_with_ATR_with_RWM_2.json
# BENCHMARK_DCA_with_SPY_4.json	 SMA_with_ATR_with_RWM_3.json
# BENCHMARK_DCA_with_SPY_5.json	 SMA_with_ATR_with_RWM_4.json
# BENCHMARK_DCA_with_SPY_6.json	 SMA_with_ATR_with_RWM_5.json
# BENCHMARK_DCA_with_SPY_7.json	 SMA_with_ATR_with_RWM_6.json
# BENCHMARK_DCA_with_SPY_8.json	 SMA_with_ATR_with_RWM_7.json
# BENCHMARK_DCA_with_SPY_9.json	 SMA_with_ATR_with_RWM_8.json
# cagr.csv			 SMA_with_ATR_with_RWM_9.json
# drawdown.csv			 SMA_with_ATR_with_SH_0.json
# EMA_ATR_with_RWM_0.json		 SMA_with_ATR_with_SH_10.json
# EMA_ATR_with_RWM_10.json	 SMA_with_ATR_with_SH_11.json
# EMA_ATR_with_RWM_11.json	 SMA_with_ATR_with_SH_1.json
# EMA_ATR_with_RWM_1.json		 SMA_with_ATR_with_SH_2.json
# EMA_ATR_with_RWM_2.json		 SMA_with_ATR_with_SH_3.json
# EMA_ATR_with_RWM_3.json		 SMA_with_ATR_with_SH_4.json
# EMA_ATR_with_RWM_4.json		 SMA_with_ATR_with_SH_5.json
# EMA_ATR_with_RWM_5.json		 SMA_with_ATR_with_SH_6.json
# EMA_ATR_with_RWM_6.json		 SMA_with_ATR_with_SH_7.json
# EMA_ATR_with_RWM_7.json		 SMA_with_ATR_with_SH_8.json
# EMA_ATR_with_RWM_8.json		 SMA_with_ATR_with_SH_9.json
# EMA_ATR_with_RWM_9.json		 SMA_with_ATR_with_SPY_0.json
# EMA_ATR_with_SH_0.json		 SMA_with_ATR_with_SPY_10.json
# EMA_ATR_with_SH_10.json		 SMA_with_ATR_with_SPY_11.json
# EMA_ATR_with_SH_11.json		 SMA_with_ATR_with_SPY_1.json
# EMA_ATR_with_SH_1.json		 SMA_with_ATR_with_SPY_2.json
# EMA_ATR_with_SH_2.json		 SMA_with_ATR_with_SPY_3.json
# EMA_ATR_with_SH_3.json		 SMA_with_ATR_with_SPY_4.json
# EMA_ATR_with_SH_4.json		 SMA_with_ATR_with_SPY_5.json
# EMA_ATR_with_SH_5.json		 SMA_with_ATR_with_SPY_6.json
# EMA_ATR_with_SH_6.json		 SMA_with_ATR_with_SPY_7.json
# EMA_ATR_with_SH_7.json		 SMA_with_ATR_with_SPY_8.json
# EMA_ATR_with_SH_8.json		 SMA_with_ATR_with_SPY_9.json
# EMA_ATR_with_SH_9.json		 twr.csv

# %%
"""
HAC/Newey–West t-test for QuantConnect backtest JSONs
"""

import json
import math
import os
from glob import glob
from typing import Dict, Iterable, List, Optional, Tuple

import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.multitest import multipletests
from scipy.stats import norm

SCIPY_SURVIVAL_FUNCTION = getattr(norm, "sf")


def _daily_last_unique(source_series: pd.Series) -> pd.Series:
    """Return daily last observation with stable timezone handling."""
    parsed_index = pd.to_datetime(
        source_series.index, utc=True, errors="coerce"
    )
    numeric_series = pd.Series(
        pd.to_numeric(source_series.to_numpy(copy=False), errors="coerce"),
        index=parsed_index,
    )
    cleaned = numeric_series[~numeric_series.index.isna()]
    cleaned = cleaned.dropna()
    if cleaned.empty:
        return pd.Series(dtype=float)
    cleaned.index = pd.DatetimeIndex(cleaned.index).tz_convert(None)
    cleaned = cleaned.sort_index()
    cleaned = cleaned[~cleaned.index.duplicated(keep="last")]
    cleaned = cleaned.resample("D").last().dropna()
    return cleaned.astype(float)

# Helpers to read QC charts

def _first_non_empty_series(charts: Dict) -> Optional[pd.Series]:
    if charts is None:
        return None

    def _extract_values(series_object) -> Optional[pd.Series]:
        series_values = None
        if isinstance(series_object, dict):
            series_values = series_object.get("values") or series_object.get(
                "Values"
            )
        if not series_values or not isinstance(series_values, list):
            return None
        parsed_rows = []
        for point in series_values:
            if not isinstance(point, dict):
                continue
            raw_timestamp = (
                point.get("x")
                or point.get("time")
                or point.get("t")
                or point.get("date")
            )
            raw_value = point.get("y") or point.get("value") or point.get("v")
            if raw_value is None or raw_timestamp is None:
                continue
            try:
                numeric_value = float(raw_value)
            except (TypeError, ValueError):
                continue
            if not math.isfinite(numeric_value):
                continue
            timestamp = pd.to_datetime(
                raw_timestamp,
                utc=True,
                errors="coerce",
            )
            if pd.isna(timestamp):
                continue
            parsed_rows.append((timestamp, numeric_value))
        if not parsed_rows:
            return None
        timestamp_index, values = zip(*parsed_rows)
        extracted_series = pd.Series(
            values, index=pd.DatetimeIndex(timestamp_index)
        )
        extracted_series = _daily_last_unique(extracted_series)
        if extracted_series.empty:
            return None
        return extracted_series

    preferred_chart_names = [
        "TWR NAV",
        "Strategy Equity",
        "Equity",
        "Portfolio Equity",
    ]
    for preferred_name in preferred_chart_names:
        chart = (
            charts.get(preferred_name) if isinstance(charts, dict) else None
        )
        if not isinstance(chart, dict):
            continue
        series_dict = chart.get("series") or chart.get("Series") or {}
        if isinstance(series_dict, dict):
            for series_name in ["NAV", "Equity", "Strategy Equity"]:
                series_object = series_dict.get(series_name)
                extracted_series = (
                    _extract_values(series_object) if series_object else None
                )
                if extracted_series is not None and len(extracted_series) > 1:
                    return extracted_series
            for series_object in series_dict.values():
                extracted_series = _extract_values(series_object)
                if extracted_series is not None and len(extracted_series) > 1:
                    return extracted_series

    if isinstance(charts, dict):
        for chart in charts.values():
            if not isinstance(chart, dict):
                continue
            series_dict = chart.get("series") or chart.get("Series") or {}
            if isinstance(series_dict, dict):
                for series_object in series_dict.values():
                    extracted_series = _extract_values(series_object)
                    if (
                        extracted_series is not None
                        and len(extracted_series) > 1
                    ):
                        return extracted_series
    return None


def load_qc_equity_series(path: str):
    """Return series, label, and shift extracted from a QC backtest JSON."""
    with open(path, "r", encoding="utf-8") as file_handle:
        json_blob = json.load(file_handle)
    charts = json_blob.get("charts") or json_blob.get("Charts")
    equity_series = _first_non_empty_series(charts)
    if equity_series is not None:
        equity_series = _daily_last_unique(equity_series)
        if equity_series.empty:
            equity_series = None
    if equity_series is None:
        # Fallback: try rollingWindow->portfolioStatistics->endEquity
        rolling_window = json_blob.get("rollingWindow") or {}
        rows = []
        for window_key, window_value in rolling_window.items():
            portfolio_stats = (window_value or {}).get(
                "portfolioStatistics"
            ) or {}
            end_equity = portfolio_stats.get("endEquity")
            date_token = None
            if "_" in window_key:
                date_token = window_key.split("_", 1)[1]
            if end_equity is not None and date_token is not None:
                try:
                    rows.append(
                        (
                            pd.to_datetime(
                                date_token,
                                utc=True,
                                errors="coerce",
                            ),
                            float(end_equity),
                        )
                    )
                except Exception:
                    pass
        if rows:
            valid_rows = [
                (timestamp, value)
                for timestamp, value in rows
                if pd.notna(timestamp)
            ]
            if valid_rows:
                index_values, equity_values = zip(*valid_rows)
                equity_series = pd.Series(
                    equity_values, index=pd.DatetimeIndex(index_values)
                )
                equity_series = _daily_last_unique(equity_series)
            else:
                equity_series = None
        if equity_series is None or equity_series.empty:
            raise ValueError(f"Could not extract a usable series from {path}.")
    label = os.path.basename(path)
    parameter_config = json_blob.get("parameterSet") or {}
    shift_raw = (
        parameter_config.get("BacktestShiftMonths")
        or parameter_config.get("backtestShiftMonths")
        or "0"
    )
    try:
        shift_months = int(float(shift_raw))
    except Exception:
        shift_months = 0
    return equity_series.astype(float), label, shift_months


def equity_to_log_returns(equity_series: pd.Series) -> pd.Series:
    daily_series = _daily_last_unique(equity_series)
    if daily_series.empty:
        return pd.Series(dtype=float)
    positive_values = daily_series[daily_series > 0]
    log_returns = np.log(positive_values / positive_values.shift(1))
    log_returns = log_returns.replace([np.inf, -np.inf], np.nan).dropna()
    return log_returns


def add_multiple_testing(
    results_dataframe: pd.DataFrame,
    p_column: str = "pvalue",
    alpha: float = 0.05,
):
    """
    Adds adjusted p-values and reject flags for:
      - Bonferroni (FWER)
      - Holm (FWER)
      - Benjamini–Hochberg (FDR)
    """
    p_values = np.asarray(results_dataframe[p_column].values, dtype=float)

    adjustment_methods = [
        ("bonferroni", "bonferroni"),
        ("holm", "holm"),
        ("fdr_bh", "fdr_bh"),
    ]
    for adjustment_label, adjustment_method in adjustment_methods:
        test_result = multipletests(
            p_values, alpha=alpha, method=adjustment_method
        )
        reject_flags, adjusted_p_values = test_result[:2]
        results_dataframe[f"p_adj_{adjustment_label}"] = adjusted_p_values
        results_dataframe[f"reject_{adjustment_label}"] = reject_flags

    return results_dataframe

# Newey–West using statsmodels (HAC)

def _auto_bandwidth_L(sample_size: int) -> int:
    """Andrews (1991)-style rule of thumb used for 'auto'."""
    if sample_size <= 1:
        return 0
    bandwidth = int(math.floor(4.0 * (sample_size / 100.0) ** (2.0 / 9.0)))
    return max(0, bandwidth)


def _nw_mean_test_with_statsmodels(
    diff_log_returns: np.ndarray,
    bandwidth_lags: Optional[int],
    alpha: float,
):
    """
    Regress diff on a constant and use HAC (Newey–West) covariance to
    get the t-stat and CI for the mean. Returns tuple:
      (mean_hat, t_stat, p_two, p_gt, (ci_low, ci_up), L_used)
    """
    returns_array = np.asarray(diff_log_returns, dtype=float)
    returns_array = returns_array[np.isfinite(returns_array)]
    sample_size = returns_array.shape[0]
    if sample_size < 2:
        return (np.nan, np.nan, np.nan, np.nan, (np.nan, np.nan), 0)

    if bandwidth_lags is None or (
        isinstance(bandwidth_lags, str)
        and str(bandwidth_lags).lower() == "auto"
    ):
        bandwidth_lags = _auto_bandwidth_L(sample_size)
    max_lags = int(max(0, min(int(bandwidth_lags), max(0, sample_size - 1))))

    design_matrix = np.ones((sample_size, 1), dtype=float)
    model = sm.OLS(returns_array, design_matrix)
    fitted_model = model.fit(
        cov_type="HAC",
        cov_kwds={"maxlags": max_lags},
    )

    mean_estimate = float(fitted_model.params[0])
    t_statistic = float(fitted_model.tvalues[0])
    two_sided_p_value = float(fitted_model.pvalues[0])
    greater_p_value = (
        float(SCIPY_SURVIVAL_FUNCTION(t_statistic))
        if np.isfinite(t_statistic)
        else float("nan")
    )
    ci_low, ci_up = [
        float(confidence)
        for confidence in fitted_model.conf_int(alpha=alpha)[0]
    ]

    return (
        mean_estimate,
        t_statistic,
        two_sided_p_value,
        greater_p_value,
        (ci_low, ci_up),
        max_lags,
    )


def compare_files(
    model_path: str,
    benchmark_path: str,
    alpha: float = 0.05,
    bandwidth_lags: Optional[int] = None,
) -> dict:
    """Compare one model file to one benchmark file. Returns a dict result."""
    model_series, model_label, model_shift = load_qc_equity_series(model_path)
    benchmark_series, benchmark_label, benchmark_shift = load_qc_equity_series(
        benchmark_path
    )

    model_returns = equity_to_log_returns(model_series)
    benchmark_returns = equity_to_log_returns(benchmark_series)
    joined_returns = pd.concat(
        [model_returns, benchmark_returns], axis=1, join="inner"
    )
    joined_returns.columns = ["model", "bench"]
    joined_returns = joined_returns.dropna()
    if joined_returns.shape[0] < 3:
        raise ValueError(
            "Insufficient overlapping daily points to run the test."
        )

    return_diff = (joined_returns["model"] - joined_returns["bench"]).values
    (
        mean_estimate,
        t_statistic,
        two_sided_p_value,
        greater_p_value,
        (ci_lower, ci_upper),
        lags_used,
    ) = _nw_mean_test_with_statsmodels(return_diff, bandwidth_lags, alpha)

    model_is_better = (
        np.isfinite(greater_p_value)
        and greater_p_value < alpha
        and mean_estimate > 0.0
    )

    start_date = joined_returns.index.min()
    end_date = joined_returns.index.max()
    result = {
        "model_label": model_label,
        "benchmark_label": benchmark_label,
        "start_date": str(pd.to_datetime(start_date).date()),
        "end_date": str(pd.to_datetime(end_date).date()),
        "n_days": int(joined_returns.shape[0]),
        "L": int(lags_used),
        "mean_diff_logret": float(mean_estimate),
        "t_stat": float(t_statistic),
        "p_value_two_sided": float(two_sided_p_value),
        "p_value_one_sided_gt": float(greater_p_value),
        "ci_lower": float(ci_lower),
        "ci_upper": float(ci_upper),
        "alpha": float(alpha),
        "better_than_benchmark": bool(model_is_better),
        "shift_months_model": int(model_shift),
        "shift_months_benchmark": int(benchmark_shift),
    }
    return result


# Batch utilities

def _pair_by_shift(
    models: List[str],
    benches: List[str],
) -> List[Tuple[str, str, int]]:
    """Pair files by BacktestShiftMonths (from JSON content)."""

    def _shift(path: str):
        try:
            return load_qc_equity_series(path)[2]
        except Exception:
            return None

    model_shifts = {_shift(path): path for path in models}
    benchmark_shifts = {_shift(path): path for path in benches}
    pairs: List[Tuple[str, str, int]] = []
    for shift_value in sorted(
        set(model_shifts.keys()) & set(benchmark_shifts.keys())
    ):
        if shift_value is None:
            continue
        pairs.append(
            (
                model_shifts[shift_value],
                benchmark_shifts[shift_value],
                shift_value,
            )
        )
    return pairs


def list_pair_names(pairs: Iterable[Tuple[str, str]]) -> List[Tuple[str, str]]:
    """Return [(basename(model), basename(bench)), ...] for display/logging."""
    formatted_pairs: List[Tuple[str, str]] = []
    for pair in pairs:
        model_path, benchmark_path = pair[0], pair[1]
        formatted_pairs.append(
            (
                os.path.basename(model_path),
                os.path.basename(benchmark_path),
            )
        )
    return formatted_pairs


def _summarize_results(results: List[dict]) -> dict:
    results_dataframe = pd.DataFrame(results)
    if results_dataframe.empty:
        return {
            "n_pairs": 0,
            "n_significant_one_sided": 0,
            "share_significant": 0.0,
            "t_min": None,
            "t_median": None,
            "t_max": None,
            "mean_diff_min": None,
            "mean_diff_median": None,
            "mean_diff_max": None,
        }
    significant_count = int(
        results_dataframe["better_than_benchmark"].astype(bool).sum()
    )
    return {
        "n_pairs": int(len(results)),
        "n_significant_one_sided": significant_count,
        "share_significant": (
            float(significant_count) / float(len(results)) if results else 0.0
        ),
        "t_min": float(results_dataframe["t_stat"].min()),
        "t_median": float(results_dataframe["t_stat"].median()),
        "t_max": float(results_dataframe["t_stat"].max()),
        "mean_diff_min": float(results_dataframe["mean_diff_logret"].min()),
        "mean_diff_median": float(
            results_dataframe["mean_diff_logret"].median()
        ),
        "mean_diff_max": float(results_dataframe["mean_diff_logret"].max()),
    }


def _maybe_save(
    results: List[dict],
    summary: dict,
    out_json: Optional[str] = None,
    out_csv: Optional[str] = None,
):
    results_dataframe = pd.DataFrame(results)
    if out_json:
        blob = {"results": results, "summary": summary}
        with open(out_json, "w", encoding="utf-8") as file_handle:
            file_handle.write(json.dumps(blob, indent=2) + "\n")
    if out_csv:
        results_dataframe.to_csv(out_csv, index=False)
    return results_dataframe


# Public batch entry points


def compare_from_list(
    pairs: Iterable[Tuple[str, str]],
    alpha: float = 0.05,
    bandwidth_lags: Optional[int] = "auto",
    out_json: Optional[str] = None,
    out_csv: Optional[str] = None,
):
    """
    Compare a list of (model_path, benchmark_path) pairs.
    Returns (results_list, summary_dict, results_df).
    Optionally saves to out_json (full blob) and/or out_csv (row-wise results).
    """
    # Normalize bandwidth input
    if isinstance(bandwidth_lags, str) and bandwidth_lags.lower() != "auto":
        bandwidth_lags = int(bandwidth_lags)

    comparison_results: List[dict] = []
    for model_path, benchmark_path in pairs:
        comparison_record = compare_files(
            model_path,
            benchmark_path,
            alpha=alpha,
            bandwidth_lags=bandwidth_lags,
        )
        comparison_results.append(comparison_record)

    summary = _summarize_results(comparison_results)
    results_dataframe = _maybe_save(
        comparison_results,
        summary,
        out_json=out_json,
        out_csv=out_csv,
    )
    return comparison_results, summary, results_dataframe


def compare_all_against_benchmark(
    models: List[str],
    benchmark_path: str,
    alpha: float = 0.05,
    bandwidth_lags: Optional[int] = "auto",
    out_json: Optional[str] = None,
    out_csv: Optional[str] = None,
):
    """Compare each model in `models` against a single benchmark file."""
    pairs = [(model_path, benchmark_path) for model_path in models]
    return compare_from_list(
        pairs,
        alpha=alpha,
        bandwidth_lags=bandwidth_lags,
        out_json=out_json,
        out_csv=out_csv,
    )


def compare_from_two_lists(
    models: List[str],
    benches: List[str],
    alpha: float = 0.05,
    bandwidth_lags: Optional[int] = "auto",
    out_json: Optional[str] = None,
    out_csv: Optional[str] = None,
):
    """Zip two lists by order and compare."""
    list_length = min(len(models), len(benches))
    pairs = list(zip(models[:list_length], benches[:list_length]))
    return compare_from_list(
        pairs,
        alpha=alpha,
        bandwidth_lags=bandwidth_lags,
        out_json=out_json,
        out_csv=out_csv,
    )


def compare_from_globs(
    model_glob: str,
    benchmark_glob: str,
    alpha: float = 0.05,
    bandwidth_lags: Optional[int] = "auto",
    out_json: Optional[str] = None,
    out_csv: Optional[str] = None,
):
    """
    Compare using file globs. Attempts auto-pairing by BacktestShiftMonths;
    if no shifts match, falls back to sorted zip. Returns
    (results, summary, results_dataframe, used_pairs).
    """
    models = sorted(glob(model_glob))
    benches = sorted(glob(benchmark_glob))
    if not models or not benches:
        raise ValueError("No files matched the provided globs.")

    pairs_by_shift = _pair_by_shift(models, benches)
    if pairs_by_shift:
        pairs = []
        for model_path, benchmark_path, shift_value in pairs_by_shift:
            if shift_value is None:
                continue
            pairs.append((model_path, benchmark_path))
    else:
        pairs = list(zip(models, benches))

    results, summary, results_dataframe = compare_from_list(
        pairs,
        alpha=alpha,
        bandwidth_lags=bandwidth_lags,
        out_json=out_json,
        out_csv=out_csv,
    )
    return results, summary, results_dataframe, pairs


# Pretty helpers for notebooks


def results_to_dataframe(results: List[dict]) -> pd.DataFrame:
    return pd.DataFrame(results)


def show_pairs(pairs: Iterable[Tuple[str, str]]):
    names = list_pair_names(pairs)
    return pd.DataFrame(names, columns=["model", "benchmark"])

# %%
import glob
import os
import re
from pprint import pprint

BASE = "/content/drive/MyDrive/AlgoA2/Test Result"  # e.g., "/path/to/jsons"
PATTERN = os.path.join(BASE, "*.json")

files = [
    os.path.basename(file_path) for file_path in glob.glob(PATTERN)
]


def extract_index(file_name: str):
    match = re.search(r"_(\d+)\.json$", file_name)
    return int(match.group(1)) if match else None


def extract_asset(file_name: str):
    # Picks up the last "...with_ASSET_N.json" token
    match = re.search(r"with_([A-Za-z0-9]+)_(\d+)\.json$", file_name)
    return match.group(1) if match else None


benchmarks = [
    file_name
    for file_name in files
    if file_name.startswith("BENCHMARK_DCA_with_")
]
others = [
    file_name
    for file_name in files
    if not file_name.startswith("BENCHMARK_DCA_with_")
]

# %%
benchmarks
# Out:
# ['BENCHMARK_DCA_with_IWM_11.json',
#  'BENCHMARK_DCA_with_IWM_10.json',
#  'BENCHMARK_DCA_with_IWM_9.json',
#  'BENCHMARK_DCA_with_IWM_8.json',
#  'BENCHMARK_DCA_with_IWM_7.json',
#  'BENCHMARK_DCA_with_IWM_6.json',
#  'BENCHMARK_DCA_with_IWM_5.json',
#  'BENCHMARK_DCA_with_IWM_4.json',
#  'BENCHMARK_DCA_with_IWM_3.json',
#  'BENCHMARK_DCA_with_IWM_2.json',
#  'BENCHMARK_DCA_with_IWM_1.json',
#  'BENCHMARK_DCA_with_IWM_0.json',
#  'BENCHMARK_DCA_with_SH_11.json',
#  'BENCHMARK_DCA_with_SH_10.json',
#  'BENCHMARK_DCA_with_SH_9.json',
#  'BENCHMARK_DCA_with_SH_8.json',
#  'BENCHMARK_DCA_with_SH_7.json',
#  'BENCHMARK_DCA_with_SH_6.json',
#  'BENCHMARK_DCA_with_SH_5.json',
#  'BENCHMARK_DCA_with_SH_4.json',
#  'BENCHMARK_DCA_with_SH_3.json',
#  'BENCHMARK_DCA_with_SH_2.json',
#  'BENCHMARK_DCA_with_SH_1.json',
#  'BENCHMARK_DCA_with_SH_0.json',
#  'BENCHMARK_DCA_with_SPY_11.json',
#  'BENCHMARK_DCA_with_SPY_10.json',
#  'BENCHMARK_DCA_with_SPY_9.json',
#  'BENCHMARK_DCA_with_SPY_8.json',
#  'BENCHMARK_DCA_with_SPY_7.json',
#  'BENCHMARK_DCA_with_SPY_6.json',
#  'BENCHMARK_DCA_with_SPY_5.json',
#  'BENCHMARK_DCA_with_SPY_4.json',
#  'BENCHMARK_DCA_with_SPY_3.json',
#  'BENCHMARK_DCA_with_SPY_2.json',
#  'BENCHMARK_DCA_with_SPY_1.json',
#  'BENCHMARK_DCA_with_SPY_0.json',
#  'BENCHMARK_DCA_with_RWM_11.json',
#  'BENCHMARK_DCA_with_RWM_10.json',
#  'BENCHMARK_DCA_with_RWM_9.json',
#  'BENCHMARK_DCA_with_RWM_8.json',
#  'BENCHMARK_DCA_with_RWM_7.json',
#  'BENCHMARK_DCA_with_RWM_6.json',
#  'BENCHMARK_DCA_with_RWM_5.json',
#  'BENCHMARK_DCA_with_RWM_4.json',
#  'BENCHMARK_DCA_with_RWM_3.json',
#  'BENCHMARK_DCA_with_RWM_2.json',
#  'BENCHMARK_DCA_with_RWM_1.json',
#  'BENCHMARK_DCA_with_RWM_0.json']

# %%
len(benchmarks)
# Out:
# 48

# %%
others
# Out:
# ['RSI_FILTER_ONLY_with_RWM_11.json',
#  'RSI_FILTER_ONLY_with_RWM_10.json',
#  'RSI_FILTER_ONLY_with_RWM_9.json',
#  'RSI_FILTER_ONLY_with_RWM_8.json',
#  'RSI_FILTER_ONLY_with_RWM_7.json',
#  'RSI_FILTER_ONLY_with_RWM_6.json',
#  'RSI_FILTER_ONLY_with_RWM_5.json',
#  'RSI_FILTER_ONLY_with_RWM_4.json',
#  'RSI_FILTER_ONLY_with_RWM_3.json',
#  'RSI_FILTER_ONLY_with_RWM_2.json',
#  'RSI_FILTER_ONLY_with_RWM_1.json',
#  'RSI_FILTER_ONLY_with_RWM_0.json',
#  'RSI_FILTER_ONLY_with_SH_11.json',
#  'RSI_FILTER_ONLY_with_SH_10.json',
#  'RSI_FILTER_ONLY_with_SH_9.json',
#  'RSI_FILTER_ONLY_with_SH_8.json',
#  'RSI_FILTER_ONLY_with_SH_7.json',
#  'RSI_FILTER_ONLY_with_SH_6.json',
#  'RSI_FILTER_ONLY_with_SH_5.json',
#  'RSI_FILTER_ONLY_with_SH_4.json',
#  'RSI_FILTER_ONLY_with_SH_3.json',
#  'RSI_FILTER_ONLY_with_SH_2.json',
#  'RSI_FILTER_ONLY_with_SH_1.json',
#  'RSI_FILTER_ONLY_with_SH_0.json',
#  'RSI_FILTER_ONLY_with_SPY_11.json',
#  'RSI_FILTER_ONLY_with_SPY_10.json',
#  'RSI_FILTER_ONLY_with_SPY_9.json',
#  'RSI_FILTER_ONLY_with_SPY_8.json',
#  'RSI_FILTER_ONLY_with_SPY_7.json',
#  'RSI_FILTER_ONLY_with_SPY_6.json',
#  'RSI_FILTER_ONLY_with_SPY_5.json',
#  'RSI_FILTER_ONLY_with_SPY_4.json',
#  'RSI_FILTER_ONLY_with_SPY_3.json',
#  'RSI_FILTER_ONLY_with_SPY_2.json',
#  'RSI_FILTER_ONLY_with_SPY_1.json',
#  'RSI_FILTER_ONLY_with_SPY_0.json',
#  'RSI_FILTER_ONLY_with_IWM_11.json',
#  'RSI_FILTER_ONLY_with_IWM_10.json',
#  'RSI_FILTER_ONLY_with_IWM_9.json',
#  'RSI_FILTER_ONLY_with_IWM_8.json',
#  'RSI_FILTER_ONLY_with_IWM_7.json',
#  'RSI_FILTER_ONLY_with_IWM_6.json',
#  'RSI_FILTER_ONLY_with_IWM_5.json',
#  'RSI_FILTER_ONLY_with_IWM_4.json',
#  'RSI_FILTER_ONLY_with_IWM_3.json',
#  'RSI_FILTER_ONLY_with_IWM_2.json',
#  'RSI_FILTER_ONLY_with_IWM_1.json',
#  'RSI_FILTER_ONLY_with_IWM_0.json',
#  'BB_FILTER_ONLY_with_IWM_11.json',
#  'BB_FILTER_ONLY_with_IWM_10.json',
#  'BB_FILTER_ONLY_with_IWM_9.json',
#  'BB_FILTER_ONLY_with_IWM_8.json',
#  'BB_FILTER_ONLY_with_IWM_7.json',
#  'BB_FILTER_ONLY_with_IWM_6.json',
#  'BB_FILTER_ONLY_with_IWM_5.json',
#  'BB_FILTER_ONLY_with_IWM_4.json',
#  'BB_FILTER_ONLY_with_IWM_3.json',
#  'BB_FILTER_ONLY_with_IWM_2.json',
#  'BB_FILTER_ONLY_with_IWM_1.json',
#  'BB_FILTER_ONLY_with_IWM_0.json',
#  'BB_FILTER_ONLY_with_RWM_11.json',
#  'BB_FILTER_ONLY_with_RWM_10.json',
#  'BB_FILTER_ONLY_with_RWM_9.json',
#  'BB_FILTER_ONLY_with_RWM_8.json',
#  'BB_FILTER_ONLY_with_RWM_7.json',
#  'BB_FILTER_ONLY_with_RWM_6.json',
#  'BB_FILTER_ONLY_with_RWM_5.json',
#  'BB_FILTER_ONLY_with_RWM_4.json',
#  'BB_FILTER_ONLY_with_RWM_3.json',
#  'BB_FILTER_ONLY_with_RWM_2.json',
#  'BB_FILTER_ONLY_with_RWM_1.json',
#  'BB_FILTER_ONLY_with_RWM_0.json',
#  'BB_FILTER_ONLY_with_SH_11.json',
#  'BB_FILTER_ONLY_with_SH_10.json',
#  'BB_FILTER_ONLY_with_SH_9.json',
#  'BB_FILTER_ONLY_with_SH_8.json',
#  'BB_FILTER_ONLY_with_SH_7.json',
#  'BB_FILTER_ONLY_with_SH_6.json',
#  'BB_FILTER_ONLY_with_SH_5.json',
#  'BB_FILTER_ONLY_with_SH_4.json',
#  'BB_FILTER_ONLY_with_SH_3.json',
#  'BB_FILTER_ONLY_with_SH_2.json',
#  'BB_FILTER_ONLY_with_SH_1.json',
#  'BB_FILTER_ONLY_with_SH_0.json',
#  'BB_FILTER_ONLY_with_SPY_11.json',
#  'BB_FILTER_ONLY_with_SPY_10.json',
#  'BB_FILTER_ONLY_with_SPY_9.json',
#  'BB_FILTER_ONLY_with_SPY_8.json',
#  'BB_FILTER_ONLY_with_SPY_7.json',
#  'BB_FILTER_ONLY_with_SPY_6.json',
#  'BB_FILTER_ONLY_with_SPY_5.json',
#  'BB_FILTER_ONLY_with_SPY_4.json',
#  'BB_FILTER_ONLY_with_SPY_3.json',
#  'BB_FILTER_ONLY_with_SPY_2.json',
#  'BB_FILTER_ONLY_with_SPY_1.json',
#  'BB_FILTER_ONLY_with_SPY_0.json',
#  'SMA_with_ATR_with_IWM_11.json',
#  'SMA_with_ATR_with_IWM_10.json',
#  'SMA_with_ATR_with_IWM_9.json',
#  'SMA_with_ATR_with_IWM_8.json',
#  'SMA_with_ATR_with_IWM_7.json',
#  'SMA_with_ATR_with_IWM_6.json',
#  'SMA_with_ATR_with_IWM_5.json',
#  'SMA_with_ATR_with_IWM_4.json',
#  'SMA_with_ATR_with_IWM_3.json',
#  'SMA_with_ATR_with_IWM_2.json',
#  'SMA_with_ATR_with_IWM_1.json',
#  'SMA_with_ATR_with_IWM_0.json',
#  'SMA_with_ATR_with_RWM_11.json',
#  'SMA_with_ATR_with_RWM_10.json',
#  'SMA_with_ATR_with_RWM_9.json',
#  'SMA_with_ATR_with_RWM_8.json',
#  'SMA_with_ATR_with_RWM_7.json',
#  'SMA_with_ATR_with_RWM_6.json',
#  'SMA_with_ATR_with_RWM_5.json',
#  'SMA_with_ATR_with_RWM_4.json',
#  'SMA_with_ATR_with_RWM_3.json',
#  'SMA_with_ATR_with_RWM_2.json',
#  'SMA_with_ATR_with_RWM_1.json',
#  'SMA_with_ATR_with_RWM_0.json',
#  'SMA_with_ATR_with_SH_11.json',
#  'SMA_with_ATR_with_SH_10.json',
#  'SMA_with_ATR_with_SH_9.json',
#  'SMA_with_ATR_with_SH_8.json',
#  'SMA_with_ATR_with_SH_7.json',
#  'SMA_with_ATR_with_SH_6.json',
#  'SMA_with_ATR_with_SH_5.json',
#  'SMA_with_ATR_with_SH_4.json',
#  'SMA_with_ATR_with_SH_3.json',
#  'SMA_with_ATR_with_SH_2.json',
#  'SMA_with_ATR_with_SH_1.json',
#  'SMA_with_ATR_with_SH_0.json',
#  'SMA_with_ATR_with_SPY_11.json',
#  'SMA_with_ATR_with_SPY_10.json',
#  'SMA_with_ATR_with_SPY_9.json',
#  'SMA_with_ATR_with_SPY_8.json',
#  'SMA_with_ATR_with_SPY_7.json',
#  'SMA_with_ATR_with_SPY_6.json',
#  'SMA_with_ATR_with_SPY_5.json',
#  'SMA_with_ATR_with_SPY_4.json',
#  'SMA_with_ATR_with_SPY_3.json',
#  'SMA_with_ATR_with_SPY_2.json',
#  'SMA_with_ATR_with_SPY_1.json',
#  'SMA_with_ATR_with_SPY_0.json',
#  'EMA_with_ATR_with_IWM_11.json',
#  'EMA_with_ATR_with_IWM_10.json',
#  'EMA_with_ATR_with_IWM_9.json',
#  'EMA_with_ATR_with_IWM_8.json',
#  'EMA_with_ATR_with_IWM_7.json',
#  'EMA_with_ATR_with_IWM_6.json',
#  'EMA_with_ATR_with_IWM_5.json',
#  'EMA_with_ATR_with_IWM_4.json',
#  'EMA_with_ATR_with_IWM_3.json',
#  'EMA_with_ATR_with_IWM_2.json',
#  'EMA_with_ATR_with_IWM_1.json',
#  'EMA_with_ATR_with_IWM_0.json',
#  'EMA_ATR_with_RWM_11.json',
#  'EMA_ATR_with_RWM_10.json',
#  'EMA_ATR_with_RWM_9.json',
#  'EMA_ATR_with_RWM_8.json',
#  'EMA_ATR_with_RWM_7.json',
#  'EMA_ATR_with_RWM_6.json',
#  'EMA_ATR_with_RWM_5.json',
#  'EMA_ATR_with_RWM_4.json',
#  'EMA_ATR_with_RWM_3.json',
#  'EMA_ATR_with_RWM_2.json',
#  'EMA_ATR_with_RWM_1.json',
#  'EMA_ATR_with_RWM_0.json',
#  'EMA_ATR_with_SH_11.json',
#  'EMA_ATR_with_SH_10.json',
#  'EMA_ATR_with_SH_9.json',
#  'EMA_ATR_with_SH_8.json',
#  'EMA_ATR_with_SH_7.json',
#  'EMA_ATR_with_SH_6.json',
#  'EMA_ATR_with_SH_5.json',
#  'EMA_ATR_with_SH_4.json',
#  'EMA_ATR_with_SH_3.json',
#  'EMA_ATR_with_SH_2.json',
#  'EMA_ATR_with_SH_1.json',
#  'EMA_ATR_with_SH_0.json',
#  'EMA_ATR_with_SPY_11.json',
#  'EMA_ATR_with_SPY_10.json',
#  'EMA_ATR_with_SPY_9.json',
#  'EMA_ATR_with_SPY_8.json',
#  'EMA_ATR_with_SPY_7.json',
#  'EMA_ATR_with_SPY_6.json',
#  'EMA_ATR_with_SPY_5.json',
#  'EMA_ATR_with_SPY_4.json',
#  'EMA_ATR_with_SPY_3.json',
#  'EMA_ATR_with_SPY_2.json',
#  'EMA_ATR_with_SPY_1.json',
#  'EMA_ATR_with_SPY_0.json']

# %%
len(others)
# Out:
# 192

# %%
others_by_idx_asset = {}
for other_file_name in others:
    index_value = extract_index(other_file_name)
    asset = extract_asset(other_file_name)
    if index_value is None or asset is None:
        continue
    others_by_idx_asset.setdefault((index_value, asset), []).append(
        other_file_name
    )

pairs_asset = []
for benchmark_file_name in benchmarks:
    index_value = extract_index(benchmark_file_name)
    asset = extract_asset(benchmark_file_name)
    if index_value is None or asset is None:
        continue
    for candidate_file_name in others_by_idx_asset.get(
        (index_value, asset), []
    ):
        pairs_asset.append(
            (
                os.path.join(BASE, candidate_file_name),
                os.path.join(BASE, benchmark_file_name),
            )
        )

print(f"Total pairs (index+asset): {len(pairs_asset)}")
# Out:
# Total pairs (index+asset): 192

# %%
pairs_asset
# Out:
# [('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_IWM_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_IWM_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_IWM_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_with_ATR_with_IWM_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_IWM_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SH_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SH_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SH_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SH_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SH_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_SPY_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_SPY_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_SPY_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_SPY_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_SPY_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_11.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_11.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_10.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_10.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_9.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_9.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_8.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_8.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_7.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_7.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_6.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_6.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_5.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_5.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_4.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_4.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_3.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_3.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_2.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_2.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_1.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_1.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/RSI_FILTER_ONLY_with_RWM_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/BB_FILTER_ONLY_with_RWM_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/SMA_with_ATR_with_RWM_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_0.json'),
#  ('/content/drive/MyDrive/AlgoA2/Test Result/EMA_ATR_with_RWM_0.json',
#   '/content/drive/MyDrive/AlgoA2/Test Result/BENCHMARK_DCA_with_RWM_0.json')]

# %%
results, summary, results_dataframe = compare_from_list(
    pairs_asset,
    alpha=0.05,
    bandwidth_lags="auto",
    out_json="hac_results.json",   # writes {"results":[...], "summary":{...}}
    out_csv="hac_results.csv"      # writes a row per comparison
)
display(show_pairs(pairs_asset))
display(results_dataframe)
summary
# Out:
#                                 model                       benchmark
# 0    RSI_FILTER_ONLY_with_IWM_11.json  BENCHMARK_DCA_with_IWM_11.json
# 1     BB_FILTER_ONLY_with_IWM_11.json  BENCHMARK_DCA_with_IWM_11.json
# 2       SMA_with_ATR_with_IWM_11.json  BENCHMARK_DCA_with_IWM_11.json
# 3       EMA_with_ATR_with_IWM_11.json  BENCHMARK_DCA_with_IWM_11.json
# 4    RSI_FILTER_ONLY_with_IWM_10.json  BENCHMARK_DCA_with_IWM_10.json
# ..                                ...                             ...
# 187           EMA_ATR_with_RWM_1.json   BENCHMARK_DCA_with_RWM_1.json
# 188   RSI_FILTER_ONLY_with_RWM_0.json   BENCHMARK_DCA_with_RWM_0.json
# 189    BB_FILTER_ONLY_with_RWM_0.json   BENCHMARK_DCA_with_RWM_0.json
# 190      SMA_with_ATR_with_RWM_0.json   BENCHMARK_DCA_with_RWM_0.json
# 191           EMA_ATR_with_RWM_0.json   BENCHMARK_DCA_with_RWM_0.json
#
# [192 rows x 2 columns]
#                           model_label                 benchmark_label  \
# 0    RSI_FILTER_ONLY_with_IWM_11.json  BENCHMARK_DCA_with_IWM_11.json
# 1     BB_FILTER_ONLY_with_IWM_11.json  BENCHMARK_DCA_with_IWM_11.json
# 2       SMA_with_ATR_with_IWM_11.json  BENCHMARK_DCA_with_IWM_11.json
# 3       EMA_with_ATR_with_IWM_11.json  BENCHMARK_DCA_with_IWM_11.json
# 4    RSI_FILTER_ONLY_with_IWM_10.json  BENCHMARK_DCA_with_IWM_10.json
# ..                                ...                             ...
# 187           EMA_ATR_with_RWM_1.json   BENCHMARK_DCA_with_RWM_1.json
# 188   RSI_FILTER_ONLY_with_RWM_0.json   BENCHMARK_DCA_with_RWM_0.json
# 189    BB_FILTER_ONLY_with_RWM_0.json   BENCHMARK_DCA_with_RWM_0.json
# 190      SMA_with_ATR_with_RWM_0.json   BENCHMARK_DCA_with_RWM_0.json
# 191           EMA_ATR_with_RWM_0.json   BENCHMARK_DCA_with_RWM_0.json
#
#      start_date    end_date  n_days  L  mean_diff_logret    t_stat  \
# 0    2020-01-31  2024-11-29      59  3         -0.000009 -0.007135
# 1    2020-01-31  2024-11-29      59  3          0.000066  0.053342
# 2    2020-01-31  2024-11-29      59  3          0.000664  0.496905
# 3    2020-01-31  2024-11-29      59  3          0.000711  0.890674
# 4    2019-12-31  2024-10-31      59  3          0.000385  0.403873
# ..          ...         ...     ... ..               ...       ...
# 187  2019-03-31  2024-01-31      59  3          0.000313  0.666648
# 188  2019-02-28  2023-12-29      59  3          0.000407  0.812994
# 189  2019-02-28  2023-12-29      59  3          0.000545  1.105137
# 190  2019-02-28  2023-12-29      59  3          0.000321  0.626622
# 191  2019-02-28  2023-12-29      59  3         -0.000049 -0.096469
#
#      p_value_two_sided  p_value_one_sided_gt  ci_lower  ci_upper  alpha  \
# 0             0.994307              0.502846 -0.002360  0.002343   0.05
# 1             0.957459              0.478730 -0.002349  0.002480   0.05
# 2             0.619256              0.309628 -0.001956  0.003284   0.05
# 3             0.373104              0.186552 -0.000854  0.002277   0.05
# 4             0.686306              0.343153 -0.001484  0.002254   0.05
# ..                 ...                   ...       ...       ...    ...
# 187           0.504997              0.252499 -0.000606  0.001232   0.05
# 188           0.416222              0.208111 -0.000574  0.001388   0.05
# 189           0.269100              0.134550 -0.000422  0.001512   0.05
# 190           0.530907              0.265453 -0.000684  0.001326   0.05
# 191           0.923148              0.538426 -0.001052  0.000954   0.05
#
#      better_than_benchmark  shift_months_model  shift_months_benchmark
# 0                    False                  11                      11
# 1                    False                  11                      11
# 2                    False                  11                      11
# 3                    False                  11                      11
# 4                    False                  10                      10
# ..                     ...                 ...                     ...
# 187                  False                   1                       1
# 188                  False                   0                       0
# 189                  False                   0                       0
# 190                  False                   0                       0
# 191                  False                   0                       0
#
# [192 rows x 16 columns]
# {'n_pairs': 192,
#  'n_significant_one_sided': 2,
#  'share_significant': 0.010416666666666666,
#  't_min': -1.4697895286809632,
#  't_median': 0.279394784048577,
#  't_max': 1.7911661867101598,
#  'mean_diff_min': -0.0007935859438064427,
#  'mean_diff_median': 0.00015476982494284512,
#  'mean_diff_max': 0.0015243864494188116}
